# %% [markdown]
# ### Model Intergartion with OpenAI, Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash")
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.16', 'langchain-google-genai': '4.3.5'}}, profile={'name': 'Gemini 3.5 Flash', 'release_date': '2026-05-19', 'last_updated': '2026-05-19', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high'], 'reasoning_effort_default': 'medium'}, google_api_key=SecretStr('**********'), model='gemini-3.5-flash', temperature=None, client=<google.genai.client.Client object at 0x00000187A59D68D0>, default_metadata=(), model_kwargs={})

# %%
# invoke the model
response = model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': "Hello! I'm doing well, thank you for asking. How are you doing today? How can I help you?", 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a02dd9-3908-70d3-ab2f-df667599bde1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 299, 'total_tokens': 305, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 274}})

# %%
response.content
# Out:
# [{'type': 'text',
#   'text': "Hello! I'm doing well, thank you for asking. How are you doing today? How can I help you?",
#   'extras': {'signature': '...'}}]

# %% [markdown]
# ### Google Gemini Model Intergration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

model = init_chat_model("google_genai:gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# [{'type': 'text',
#   'text': 'Parrots talk primarily because they are **social learners** and use vocal mimicry to build relationships, identify family members, and claim territory. \n\nWhile a human hears "words," a parrot hears a tool for social connection. Here is a breakdown of why and how they do it:\n\n### 1. The Need for Social Connection (Flock Mentality)\nIn the wild, parrots live in large, noisy flocks. To survive, they need to fit in. They learn the specific "dialects" or contact calls of their family and flock mates. \n* When a parrot lives in a human home, **humans are its flock**. \n* Because parrots are hardwired to imitate the sounds of their social group to gain acceptance, they imitate human speech, household noises, microwave beeps, and phone ringtones.\n\n### 2. Brain Power and Anatomy\nParrots are among the smartest birds on the planet. They have a large forebrain, which is associated with intelligence and complex social interactions. \n* **The Syrinx:** Unlike humans, who use vocal cords in the larynx to speak, birds use an organ called the **syrinx**, located at the base of the trachea. \n* **The Tongue:** Parrots can manipulate the shape of their trachea and use their muscular tongue to shape sounds with incredible accuracy, allowing them to mimic human vowels and consonants.\n\n### 3. Getting Attention and Rewards\nParrots quickly learn that talking gets a reaction. If a parrot says "Hello!" and a human yells back, laughs, or gives it a treat, the parrot learns that talking is a powerful way to control its environment. \n* If a parrot yells "Want a cracker?" and *gets* a cracker, it will repeat that phrase whenever it wants food.\n\n### 4. Boredom and Self-Amusement\nParrots are high-energy, highly intelligent animals that need mental stimulation. If they are left alone for long periods without enough toys or interaction, they may talk simply to pass the time. (This is similar to how humans might hum or talk to themselves when bored.)\n\n---\n\n### Do they actually understand what they are saying?\nSometimes, yes! While many parrots just mimic sounds without knowing what they mean, they are fully capable of **associating words with concepts**. \n\nThe most famous example is an African Grey parrot named **Alex**, studied by Dr. Irene Pepperberg. Alex didn\'t just mimic human speech; he correctly identified colors, shapes, and numbers, and could even ask for specific foods by name. \n\nHowever, for most pet parrots, a phrase like "I love you" is understood as a greeting or a way to get attention, rather than a deep emotional declaration.',
#   'extras': {'signature': 'El4KXAERTTIPwJJLuybKkVvlt72uGaxnxikc5LIBii/5lvitWirgqUXUswVAQ9emFUhuV0ulvvShheNmjVCd5QOAYrH+SleSiluUcqx94qGbgviTt/X+MloO7zR32Ckz'}}]

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Parrots talk primarily because they are **social learners** and **vocal mimics**. In the wild, their survival and social structure depend heavily on their ability to imitate sounds. \n\nHere is a breakdown of why and how parrots talk:\n\n### 1. Social Bonding and Flocking\nIn the wild, parrots live in large, close-knit flocks. To fit in, find a mate, and stay connected with family members, they need to learn the specific "dialect" or calls of their flock. Young parrots learn these sounds from their parents. \n\n### 2. Translating to Human Homes\nWhen a parrot is kept as a pet, its human family becomes its "flock." Because parrots are hardwired to imitate the sounds of their social group, they mimic human speech, household noises (like microwaves, doorbells, or phones), and other pets to **integrate into the family**.\n\n### 3. Gaining Attention and Getting Results\nParrots quickly learn that human words are powerful tools. If a parrot says "Hello," "Want a cracker?" or even a curse word, and it results in humans running over, talking back, or giving them food, the parrot learns that **talking makes things happen**. It is a form of operant conditioning.\n\n### 4. High Intelligence and Boredom\nParrots are among the most intelligent birds on earth, possessing the cognitive abilities of a toddler. In captivity, they have complex brains that need stimulation. Mimicking human speech is often a fun game, a way to play with sound, or a coping mechanism for boredom.\n\n---\n\n### *How* Do They Talk? (Since they don\'t have lips)\nHumans use lips, teeth, and a tongue to shape sounds. Birds don’t have lips or teeth, and their tongue is very different from ours. \n\nInstead, parrots use a specialized vocal organ called the **syrinx** (located at the base of their trachea) and manipulate the shape of their **throat, tongue, and beak** to articulate vowels and consonants with astonishing accuracy. \n\n### Do they understand what they are saying?\nWhile most parrots simply mimic sounds because they sound interesting or get a reaction, some highly intelligent species—most famously **Grey Parrots** (like Alex, studied by Dr. Irene Pepperberg)—can learn the actual meanings of words and use them in context to communicate desires, colors, and numbers.', 'extras': {'signature': 'El4KXAERTTIPZEt4cAzH22x7guuNnQSvlvL4fzIo5ibAS77dHagI12Uk21sbeEhAex5XUGZnCWSUFz9iiqu0ZY7FoqTdYY1cWvQX/E/rONgmVNlFvbLwTCf+uXL+mpwq'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a02ec8-6511-7341-8811-cc41e1a895a9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 497, 'total_tokens': 503, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# ### ChatOpenAI

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4.1")
response = model.invoke("Hello How Are You?")
response

# %% [markdown]
# ### GROQ Model Integartion

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:qwen/qwen3.6-27b")
response=model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do parrots talk?" This is a straightforward biological/behavioral question about parrot vocalization and speech mimicry.\n\n2.  **Identify Key Concepts**:\n   - Parrots don\'t actually "talk" in the human sense (they don\'t understand language semantically like humans do)\n   - They are highly vocal birds with specialized anatomy\n   - They mimic sounds for social, communicative, and environmental reasons\n   - Key factors: syrinx structure, brain regions (vocal learning), social bonding, flock behavior, environmental adaptation\n\n3.  **Scientific Explanation**:\n   - **Anatomy**: Parrots have a highly developed syrinx (vocal organ) that allows precise control over sound production\n   - **Neurology**: They possess specialized brain regions for vocal learning (similar to songbirds and humans), particularly the "song system" homologs\n   - **Behavioral/Ecological Reasons**: \n     - In the wild, parrots live in flocks and use vocalizations for communication, bonding, and maintaining group cohesion\n     - Mimicking sounds helps them integrate into social groups\n     - In captivity, they mimic human speech to bond with owners, seek attention, or respond to social cues\n   - **Cognitive Aspect**: They associate sounds with contexts/outcomes (operant conditioning), not true language comprehension\n\n4.  **Structure the Response**:\n   - Clarify that parrots don\'t "talk" like humans (no semantic understanding)\n   - Explain the biological/physical reasons (syrinx, brain structure)\n   - Explain the behavioral/social reasons (flock bonding, mimicry as social tool)\n   - Explain the captive context (why they mimic humans specifically)\n   - Keep it clear, accurate, and accessible\n\n5.  **Draft Response (Mental Refinement)**:\n   Parrots don’t actually “talk” in the way humans do—they don’t understand grammar or meaning. Instead, they’re exceptional mimics. Several factors explain this:\n   - **Specialized anatomy**: Parrots have a highly developed syrinx (their vocal organ) with fine muscle control, allowing them to produce a wide range of sounds, including human speech.\n   - **Brain wiring**: Like songbirds and humans, parrots have specialized brain regions for vocal learning. They’re born with the ability to listen, memorize, and reproduce sounds.\n   - **Social behavior**: In the wild, parrots live in close-knit flocks where vocal communication is essential for bonding, identifying group members, and maintaining contact. Mimicking sounds helps them integrate socially.\n   - **Captivity adaptation**: When raised by humans, parrots treat their owners as flock members. They mimic speech to bond, get attention, or respond to routines. They often learn which sounds get positive reactions (treats, praise, interaction), reinforcing the behavior.\n   While they can associate certain words with contexts (like “hello” when the door opens), they’re responding to patterns and rewards, not grasping language conceptually. Their “talking” is really sophisticated vocal mimicry driven by social needs and cognitive flexibility.\n\n6.  **Fact-Check**:\n   - Syrinx: Correct, parrots have a complex syrinx\n   - Vocal learning: Yes, parrots are vocal learners (one of the few non-mammal groups with this ability)\n   - Brain regions: Yes, homologous to songbird/human speech areas\n   - Social bonding: Well-documented in avian ethology\n   - Captive behavior: Matches research (e.g., Alex the parrot studies showed some conceptual understanding, but general speech is mimicry/associative)\n   - Clarification on language: Important to distinguish mimicry from true language comprehension\n\n   All points are scientifically accurate and appropriately nuanced.\n\n7.  **Final Output Generation**: (Matches the refined draft) Ensure tone is informative, accessible, and addresses both biological and behavioral angles. Avoid overclaiming (e.g., don\' ...

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3.6-27b")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "Why do parrots talk?" This is a common question about animal behavior, specifically parrot vocalization and speech mimicry.\n\n2.  **Identify Key Concepts**:\n   - Parrots don\'t actually "talk" like humans (they don\'t understand language in the human sense)\n   - They mimic sounds/vocalizations\n   - Evolutionary/social reasons for mimicry\n   - Biological mechanisms (syrinx, brain structures)\n   - Social bonding, flock behavior, attention-seeking\n   - Domestication/training factors\n\n3.  **Structure the Answer**:\n   - Clarify the misconception (they mimic, don\'t truly "talk")\n   - Explain the biological/physical mechanism\n   - Explain the evolutionary/social reasons\n   - Explain how human interaction influences it\n   - Keep it clear, scientifically accurate, and accessible\n\n4.  **Draft - Section by Section**:\n   *(Introduction/Clarification)*: Parrots don’t actually “talk” in the human sense—they’re highly skilled at mimicking sounds, including human speech. They don’t understand grammar or abstract meaning the way we do, but they can associate words with contexts or rewards.\n\n   *(Biological Mechanism)*: Physically, parrots have a specialized vocal organ called the syrinx (located where the trachea splits into the lungs), which is incredibly flexible and allows them to produce a wide range of sounds. They also have large, complex brains with specialized neural circuits for learning and reproducing vocalizations.\n\n   *(Evolutionary/Social Reasons)*: In the wild, parrots are highly social flock birds. Mimicry likely evolved as a way to:\n   - Bond with flock members\n   - Recognize individuals by unique calls\n   - Warn of predators\n   - Blend into their environment or deceive rivals\n   - Maintain group cohesion over long distances\n\n   *(Human Interaction/Training)*: When kept as pets, parrots often mimic human speech because:\n   - Humans are their “flock”\n   - They learn that certain sounds get attention, food, or interaction\n   - Positive reinforcement makes them repeat words/phrases\n   - Some parrot species (like African Greys, Amazons, and Macaws) are naturally more vocal and cognitively adept at mimicry\n\n   *(Caveat/Clarification)*: While some parrots can associate words with objects or actions (like Alex the African Grey), this is more about pattern recognition and conditioning than true language comprehension.\n\n5.  **Refine & Check Accuracy**:\n   - Syrinx: correct location and function\n   - Brain: nidopallium caudolaterale and other vocal learning regions (similar to songbirds, humans)\n   - Social function: well-documented in ethology\n   - Species variation: accurate\n   - Alex the parrot reference: good example of associative learning, not true language\n   - Tone: informative, scientific but accessible\n   - Avoid anthropomorphism while acknowledging impressive abilities\n\n   Check for common misconceptions: \n   - Not all parrots talk well\n   - It\'s mimicry, not conversation\n   - Driven by social needs, not just "being smart"\n\n   All points align with current ornithological and cognitive science research.\n\n6.  **Final Output Generation**: (Structure clearly, use concise language, ensure scientific accuracy, keep it engaging)\n   - Start with direct answer\n   - Break into logical sections\n   - Use bullet points or short paragraphs for readability\n   - End with a nuanced takeaway\n\n   Draft matches the refined version. Ready.✅\n</think>\n\nParrots don\'t actually "talk" in the human sense. Instead, they are **exceptional vocal mimics** that learn to reproduce sounds, including human speech, for social and communicative reasons. Here\'s why they do it:\n\n### 🔹 1. **They\'re Social Flock Animals**\nIn the wild, parrots live in tight-knit groups. Mimicry likely evolved to:\n- **Strengthen social bonds** (matching calls helps keep the flock together)\n- **Recognize ind ...
